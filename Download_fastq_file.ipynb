# %% [markdown]
# <a href="https://colab.research.google.com/github/FarahYusri12/Tutorial_chipseq/blob/main/Download_fastq_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get update #update software in linux
# !sudo apt-get install -y sra-toolkit #install software sra toolkit
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.6 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,196 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
SRR_ID1="SRR1810900" #YAP_rep1 SRX883576 SRR1810900
# !prefetch $SRR_ID1  #download .sra file
# Out:
# 2025-12-05T08:07:16 prefetch.2.11.3: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2025-12-05T08:07:16 prefetch.2.11.3: 1) Downloading 'SRR1810900'...
# 2025-12-05T08:07:16 prefetch.2.11.3: SRA Normalized Format file is being retrieved, if this is different from your preference, it may be due to current file availability.
# 2025-12-05T08:07:16 prefetch.2.11.3:  Downloading via HTTPS...
# 2025-12-05T08:07:30 prefetch.2.11.3:  HTTPS download succeed
# 2025-12-05T08:07:35 prefetch.2.11.3:  'SRR1810900' is valid
# 2025-12-05T08:07:35 prefetch.2.11.3: 1) 'SRR1810900' was downloaded successfully

# %%
# !fasterq-dump $SRR_ID1 --split-files -O.
# Out:
# spots read      : 24,549,590
# reads read      : 24,549,590
# reads written   : 24,549,590

# %%
# !gzip *.fastq # compress file

# %%
SRR_ID2="SRR1810907" #TAZ_rep1 SRX883578 SRR1810907
# !prefetch $SRR_ID2
# Out:
# 2025-12-05T08:22:45 prefetch.2.11.3: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2025-12-05T08:22:45 prefetch.2.11.3: 1) Downloading 'SRR1810907'...
# 2025-12-05T08:22:45 prefetch.2.11.3: SRA Normalized Format file is being retrieved, if this is different from your preference, it may be due to current file availability.
# 2025-12-05T08:22:45 prefetch.2.11.3:  Downloading via HTTPS...
# 2025-12-05T08:23:02 prefetch.2.11.3:  HTTPS download succeed
# 2025-12-05T08:23:07 prefetch.2.11.3:  'SRR1810907' is valid
# 2025-12-05T08:23:07 prefetch.2.11.3: 1) 'SRR1810907' was downloaded successfully

# %%
# !fasterq-dump $SRR_ID2 --split-files -O.
# Out:
# spots read      : 27,521,260
# reads read      : 27,521,260
# reads written   : 27,521,260

# %%
# !gzip *.fastq

# %%
SRR_ID3="SRR1810918" #TEAD4_rep1 SRX883582 SRR1810918
# !prefetch $SRR_ID3
# Out:
# 2025-12-05T08:38:35 prefetch.2.11.3: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2025-12-05T08:38:35 prefetch.2.11.3: 1) Downloading 'SRR1810918'...
# 2025-12-05T08:38:35 prefetch.2.11.3: SRA Normalized Format file is being retrieved, if this is different from your preference, it may be due to current file availability.
# 2025-12-05T08:38:35 prefetch.2.11.3:  Downloading via HTTPS...
# 2025-12-05T08:38:51 prefetch.2.11.3:  HTTPS download succeed
# 2025-12-05T08:38:57 prefetch.2.11.3:  'SRR1810918' is valid
# 2025-12-05T08:38:57 prefetch.2.11.3: 1) 'SRR1810918' was downloaded successfully

# %%
# !fasterq-dump $SRR_ID3 --split-files -O.
# Out:
# spots read      : 34,776,462
# reads read      : 34,776,462
# reads written   : 34,776,462

# %%
# !gzip *.fastq

# %%
SRR_ID4="SRR1810912" #IgG_rep1 SRX883580 SRR1810912
# !prefetch $SRR_ID4
# Out:
# 2025-12-05T09:00:11 prefetch.2.11.3: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2025-12-05T09:00:11 prefetch.2.11.3: 1) Downloading 'SRR1810912'...
# 2025-12-05T09:00:11 prefetch.2.11.3: SRA Normalized Format file is being retrieved, if this is different from your preference, it may be due to current file availability.
# 2025-12-05T09:00:11 prefetch.2.11.3:  Downloading via HTTPS...
# 2025-12-05T09:00:28 prefetch.2.11.3:  HTTPS download succeed
# 2025-12-05T09:00:34 prefetch.2.11.3:  'SRR1810912' is valid
# 2025-12-05T09:00:34 prefetch.2.11.3: 1) 'SRR1810912' was downloaded successfully

# %%
# !fasterq-dump $SRR_ID4 --split-files -O.
# Out:
# spots read      : 31,246,182
# reads read      : 31,246,182
# reads written   : 31,246,182

# %%
# !gzip *.fastq

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/SRR1810900.fastq.gz /content/drive/MyDrive/portfolio

# %%
# !cp /content/SRR1810907.fastq.gz /content/drive/MyDrive/portfolio

# %%
# !cp /content/SRR1810918.fastq.gz /content/drive/MyDrive/portfolio

# %%
# !cp /content/SRR1810912.fastq.gz /content/drive/MyDrive/portfolio
